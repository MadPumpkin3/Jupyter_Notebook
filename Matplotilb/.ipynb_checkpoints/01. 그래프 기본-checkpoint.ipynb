# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x1107f0250>]

# %%
plt.plot(x, y)
plt.show() # 그래프 위 텍스트가 안 보임

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프') # 한글 폰트 지정 전이라 한글이 안 뜸.
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스  글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'cmtt10',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmr10',
#  'STIXSizeFourSym',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'cmsy10',
#  'STIXSizeOneSym',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'cmmi10',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'cmex10',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmb10',
#  'Noto Sans Brahmi',
#  'Noto Serif Ahom',
#  'Gujarati MT',
#  'Hiragino Sans',
#  'Palatino',
#  'Noto Sans Ugaritic',
#  'Telugu MN',
#  'Noto Sans Takri',
#  'Georgia',
#  'Bodoni Ornaments',
#  'Kannada MN',
#  'Sana',
#  'Myanmar Sangam MN',
#  'Gurmukhi MT',
#  'Noto Sans Avestan',
#  'Khmer Sangam MN',
#  'Bradley Hand',
#  'Lucida Grande',
#  'American Typewriter',
#  'Marion',
#  'Noto Sans Syriac',
#  'Baghdad',
#  'Tamil Sangam MN',
#  'Noto Sans Sundanese',
#  'Verdana',
#  'Noto Sans Buhid',
#  'Lao MN',
#  'Noto Sans Meetei Mayek',
#  'Arial Narrow',
#  'PT Mono',
#  'Tahoma',
#  'STIXIntegralsSm',
#  'Brush Script MT',
#  'System Font',
#  'Times New Roman',
#  'KufiStandardGK',
#  '.Keyboard',
#  'Iowan Old Style',
#  'STIXSizeOneSym',
#  'Myanmar MN',
#  'Copperplate',
#  'Gurmukhi MN',
#  'Geneva',
#  'STIXSizeFiveSym',
#  'Noto Sans Linear A',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Mende Kikakui',
#  'Hiragino Sans',
#  'Wingdings',
#  'Optima',
#  'Noto Sans Saurashtra',
#  'Bangla MN',
#  'Noto Sans Multani',
#  'Al Tarikh',
#  'Comic Sans MS',
#  'STIXIntegralsD',
#  'Noto Sans Adlam',
#  'Hiragino Sans',
#  'Noto Sans Old Turkic',
#  'Courier New',
#  'Didot',
#  'STIXSizeOneSym',
#  'Noto Sans New Tai Lue',
#  'Rockwell',
#  'Georgia',
#  'Noto Sans Pahawh Hmong',
#  'Noto Sans Oriya',
#  'Chalkboard SE',
#  'Noto Sans Armenian',
#  'Noto Sans Duployan',
#  'Verdana',
#  'Noteworthy',
#  'STIXVariants',
#  '.New York',
#  'PT Serif',
#  'Arial Unicode MS',
#  'Kokonor',
#  'Courier New',
#  'Kohinoor Telugu',
#  'Raanana',
#  'Arial Narrow',
#  'Noto Sans Syloti Nagri',
#  'Apple Symbols',
#  'PT Serif Caption',
#  'Waseem',
#  'Bangla Sangam MN',
#  'Noto Sans Javanese',
#  'Oriya MN',
#  'Corsiva Hebrew',
#  'STIXNonUnicode',
#  'Herculanum',
#  'Arial Narrow',
#  'Shree Devanagari 714',
#  'Noto Sans Miao',
#  'Noto Sans Lycian',
#  'Noto Sans Hanunoo',
#  'Noto Sans Warang Citi',
#  'Helvetica Neue',
#  'Noto Sans Bassa Vah',
#  'Hoefler Text',
#  'Noto Sans Cham',
#  'Noto Sans Marchen',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans Newa',
#  'Noto Sans Imperial Aramaic',
#  'Noto Sans Nabataean',
#  'Heiti TC',
#  'Hoefler Text',
#  'Galvji',
#  'Verdana',
#  'Bodoni 72 Smallcaps',
#  'Noto Sans Samaritan',
#  'Noto Sans Elbasan',
#  'Apple Chancery',
#  'Comic Sans MS',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'DecoType Naskh',
#  'Mishafi',
#  'Noto Sans Tai Viet',
#  'STIXVariants',
#  'Devanagari Sangam MN',
#  'Tamil MN',
#  '.SF NS Mono',
#  'Ayuthaya',
#  'Songti SC',
#  'Hiragino Mincho ProN',
#  'Savoye LET',
#  'Noto Sans Hanifi Rohingya',
#  'Trebuchet MS',
#  'Avenir',
#  'Arial Black',
#  'Noto Sans Myanmar',
#  'Noto Sans Bhaiksuki',
#  'AppleGothic',
#  'Noto Sans Cypriot',
#  '.New York',
#  'Georgia',
#  'Noto Sans Mro',
#  'Hiragino Sans',
#  'Andale Mono',
#  'Noto Sans Old Italic',
#  'Hiragino Sans',
#  'STIXSizeThreeSym',
#  'ITF Devanagari',
#  'Gujarati Sangam MN',
#  'Noto Sans Old Permic',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Webdings',
#  'Noto Sans Mandaic',
#  'Noto Sans Caucasian Albanian',
#  'Menlo',
#  'Noto Sans Tai Tham',
#  'Avenir Next Condensed',
#  'STIXSizeTwoSym',
#  'Snell Roundhand',
#  'Noto Sans Batak',
#  'Apple Braille',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Lisu',
#  'Noto Nastaliq Urdu',
#  'Noto Sans Kannada',
#  'Noto Sans Chakma',
#  'Farah',
#  'Noto Sans Hatran',
#  'Thonburi',
#  'STIXIntegralsSm',
#  'Trebuchet MS',
#  'Noto Sans Masaram Gondi',
#  'Wingdings 3',
#  'Noto Sans Kayah Li',
#  'Kohinoor Bangla',
#  'Kannada Sangam MN',
#  'Farisi',
#  'STIXIntegralsUpD',
#  'InaiMathi',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'Noto Sans Mahajani',
#  'Noto Sans Lydian',
#  'Trebuchet MS',
#  'Noto Sans Khojki',
#  'Noto Sans Old Persian',
#  'Gill Sans',
#  'Skia',
#  'Courier',
#  'Euphemia UCAS',
#  'STIXSizeFourSym',
#  'Academy Engraved LET',
#  'Luminari',
#  '.Aqua Kana',
#  'DIN Alternate',
#  'Noto Sans Modi',
#  'Sinhala Sangam MN',
#  'Microsoft Sans Serif',
#  'D2Coding',
#  'Zapf Dingbats',
#  'Noto Sans Tifinagh',
#  'Impact',
#  'Arial',
#  'Seravek',
#  'Arial Hebrew',
#  'Gurmukhi Sangam MN',
#  'Al Nile',
#  'Courier New',
#  'Kefa',
#  'Devanagari MT',
#  'STIXIntegralsUp',
#  'Noto Sans PhagsPa',
#  'Courier New',
#  'Apple Braille',
#  'Telugu Sangam MN',
#  'Big Caslon',
#  'Arial Narrow',
#  'Noto Sans Coptic',
#  'Noto Serif Myanmar',
#  'Noto Sans Siddham',
#  'Plantagenet Cherokee',
#  'Bodoni 72',
#  'Apple Braille',
#  'Verdana',
#  'Bodoni 72 Oldstyle',
#  'Noto Sans Gothic',
#  'Noto Sans Limbu',
#  'Noto Sans Tai Le',
#  'STIXIntegralsD',
#  'Noto Sans Vai',
#  'Noto Sans Linear B',
#  'Symbol',
#  'STIXIntegralsUpSm',
#  'Trebuchet MS',
#  'Noto Sans Buginese',
#  'PT Sans',
#  'Sinhala MN',
#  'Noto Sans Lepcha',
#  'STIXGeneral',
#  'Apple Braille',
#  'Phosphate',
#  'Noto Sans Khudawadi',
#  'Malayalam Sangam MN',
#  '.SF Compact Rounded',
#  'Heiti TC',
#  'Kailasa',
#  'Geeza Pro',
#  'DIN Condensed',
#  'Noto Sans Thaana',
#  'Noto Sans Old North Arabian',
#  'Futura',
#  'Mishafi Gold',
#  'Noto Sans Meroitic',
#  'Sukhumvit Set',
#  'Chalkboard',
#  'Hiragino Maru Gothic Pro',
#  'Papyrus',
#  'STIXIntegralsUp',
#  'Noto Sans Carian',
#  'Silom',
#  'STIXNonUnicode',
#  'Diwan Thuluth',
#  'STIXNonUnicode',
#  'Noto Sans Sharada',
#  'Noto Sans Sora Sompeng',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Wancho',
#  'Noto Sans Phoenician',
#  'Kohinoor Devanagari',
#  'Arial Unicode MS',
#  'STIXGeneral',
#  'Khmer MN',
#  'Hiragino Sans',
#  'Noto Serif Yezidi',
#  'Damascus',
#  'Charter',
#  'Nadeem',
#  'Hiragino Sans GB',
#  'Athelas',
#  'Noto Sans Yi',
#  'Chalkduster',
#  'Noto Sans Osage',
#  '.SF NS Mono',
#  'Beirut',
#  'STIXIntegralsUpD',
#  'Times',
#  'Helvetica',
#  'Lao Sangam MN',
#  'Cochin',
#  'Hiragino Sans',
#  'Noto Sans NKo',
#  'Hiragino Sans',
#  'Noto Sans Old Hungarian',
#  '.SF Compact',
#  'STIXSizeTwoSym',
#  'Monaco',
#  'Georgia',
#  'Tahoma',
#  'Party LET',
#  'Times New Roman',
#  'Diwan Kufi',
#  '.SF NS Rounded',
#  'Noto Sans Manichaean',
#  'Marker Felt',
#  'Arial Rounded MT Bold',
#  'Trattatello',
#  'Noto Sans Bamum',
#  'Kohinoor Gujarati',
#  'Noto Sans Inscriptional Parthian',
#  'Noto Sans Pau Cin Hau',
#  'Apple Braille',
#  'Noto Sans Osmanya',
#  '.SF Compact',
#  'Noto Sans Cuneiform',
#  'System Font',
#  'Zapfino',
#  'Apple SD Gothic Neo',
#  'Noto Sans Tirhuta',
#  'Krungthep',
#  'Oriya Sangam MN',
#  'Mshtakan',
#  'Noto Sans Kaithi',
#  'Malayalam MN',
#  'Baskerville',
#  'Sathu',
#  'Noto Sans Glagolitic',
#  'New Peninim MT',
#  'STIXSizeThreeSym',
#  'Times New Roman',
#  'Noto Serif Balinese',
#  'SignPainter',
#  'PingFang HK',
#  'Noto Sans Rejang',
#  'Avenir Next',
#  'Al Bayan',
#  'Arial',
#  'Superclarendon',
#  'Hiragino Sans',
#  'Arial',
#  'AppleMyungjo',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Tagalog',
#  'Wingdings 2',
#  'STIXGeneral',
#  'Noto Sans Mongolian',
#  'Mukta Mahee',
#  'Noto Sans Ol Chiki',
#  'Arial',
#  'Noto Sans Palmyrene',
#  '.SF Arabic',
#  'Noto Sans Gunjala Gondi',
#  'STIXIntegralsUpSm',
#  'Times New Roman',
#  'Muna']

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2]) # 마이너스 표시가 안 뜸.
# Out:
# /Users/beomtaehyeon/miniforge3/envs/MadPumpkin/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot([-1, 0, 1], [-5, -1, 2]) # 설정 후 재실행
